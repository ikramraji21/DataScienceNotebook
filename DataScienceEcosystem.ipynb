# %% [markdown]
# <H1> Data Science Tools and Ecosystem </H1>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# <b> Objectives </b> <br>
# <ul><li> List popular languages for Data Science </li>
#     <li> List popular libraries used for Data Science </li>
#     <li> List popular tools for Data Science </li>
#     <li> List a few examples of evaluating arithmetic expressions in Python</li>
# </ul>

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# <ol>
#     <li> Python </li>
#     <li> R </li>
#     <li> Java </li>
# </ol>

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# <ol> <li> Matplotlib </li>
#     <li> Numpy </li>
#     <li> Pandas </li>
# </ol>

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook |
# | R-Studio         |
# | Apache Zeppelin  |

# %% [markdown]
# <H3> Below are a few examples of evaluating arithmetic expressions in Python. </H3>

# %%
(3*4)+5 #This a simple arithmetic expression to mutiply then add integers

# %%
time = 200 * 60 #This will convert 200 minutes to hours by diving by 60
print (time)
# Out:
# 12000

# %% [markdown]
# <H2> Author </H2>
# Raji Ikram
